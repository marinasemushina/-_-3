# %%
from IPython.display import Image, display

# %% [markdown]
# Вывести распределение (количество) клиентов по сферам деятельности, отсортировав результат по убыванию количества.

# %%
display(Image(filename='/Users/marinasemushina/homework3/1.png'))

# %% [markdown]
# Найти сумму транзакций за каждый месяц по сферам деятельности, отсортировав по месяцам и по сфере деятельности.

# %%
display(Image(filename='/Users/marinasemushina/homework3/2.png'))

# %% [markdown]
# Вывести количество онлайн-заказов для всех брендов в рамках подтвержденных заказов клиентов из сферы IT

# %%
display(Image(filename='/Users/marinasemushina/homework3/3.png'))

# %% [markdown]
# Найти по всем клиентам сумму всех транзакций (list_price), максимум, минимум и количество транзакций, отсортировав результат по убыванию суммы транзакций и количества клиентов. Выполните двумя способами: используя только group by и используя только оконные функции. Сравните результат.

# %%
display(Image(filename='/Users/marinasemushina/homework3/4.1.png'))

# %%
display(Image(filename='/Users/marinasemushina/homework3/4.2.png'))

# %% [markdown]
# GROUP BY возвращает одну строку на клиента с суммой, максимумом, минимумом и количеством транзакций.
#
# Оконные функции позволяют сохранять оригинальные строки и добавляет агрегированные значения в каждую строку. Чтобы получить уникальные записи клиентов, нужно использовать DISTINCT.

# %% [markdown]
# Найти имена и фамилии клиентов с минимальной/максимальной суммой транзакций за весь период (сумма транзакций не может быть null). Напишите отдельные запросы для минимальной и максимальной суммы.

# %%
display(Image(filename='/Users/marinasemushina/homework3/5.1.png'))

# %%
display(Image(filename='/Users/marinasemushina/homework3/5.2.png'))

# %% [markdown]
# Вывести только самые первые транзакции клиентов. Решить с помощью оконных функций.

# %%
display(Image(filename='/Users/marinasemushina/homework3/6.png'))

# %% [markdown]
# Вывести имена, фамилии и профессии клиентов, между транзакциями которых был максимальный интервал (интервал вычисляется в днях)

# %%
display(Image(filename='/Users/marinasemushina/homework3/1.png'))
