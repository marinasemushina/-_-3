# %%
from IPython.display import Image, display

# %%
import pandas as pd

# %% [markdown]
# Вывести все уникальные бренды, у которых стандартная стоимость выше 1500 долларов.

# %%
display(Image(filename='/Users/marinasemushina/homework/1.png'))

# %% [markdown]
# Вывести все подтвержденные транзакции за период '2017-04-01' по '2017-04-09' включительно.

# %%
display(Image(filename='/Users/marinasemushina/homework/2.png'))

# %% [markdown]
# Вывести все профессии у клиентов из сферы IT или Financial Services, которые начинаются с фразы 'Senior'.

# %%
display(Image(filename='/Users/marinasemushina/homework/3.png'))

# %% [markdown]
# Вывести все бренды, которые закупают клиенты, работающие в сфере Financial Services

# %%
display(Image(filename='/Users/marinasemushina/homework/4.png'))

# %% [markdown]
# Вывести 10 клиентов, которые оформили онлайн-заказ продукции из брендов 'Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles'.

# %%
display(Image(filename='/Users/marinasemushina/homework/5.png'))

# %% [markdown]
# Вывести всех клиентов, у которых нет транзакций.

# %%
display(Image(filename='/Users/marinasemushina/homework/6.png'))

# %% [markdown]
# Вывести всех клиентов из IT, у которых транзакции с максимальной стандартной стоимостью.

# %%
display(Image(filename='/Users/marinasemushina/homework/7.png'))

# %% [markdown]
# Вывести всех клиентов из сферы IT и Health, у которых есть подтвержденные транзакции за период '2017-07-07' по '2017-07-17'.

# %%
display(Image(filename='/Users/marinasemushina/homework/8.png'))
